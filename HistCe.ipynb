# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages', '/cvmfs/mu2e.opensciencegrid.org/spackages/241207/spack/opt/spack/linux-almalinux9-x86_64_v2/gcc-11.5.0/muse-4.17.0-di7thnqtj43r5ojxh6gum5pqg42mwmn2/python', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python312.zip', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/lib-dynload', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import HistCe

# %%
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_debug_mc.root"]
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack.root" ]
#file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack_nofilter.root"]
#file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_test.root"]
#file = ["/data/HD6/users/brownd/ntp.CeEndpointOnSpill_full_CAFix.root"]
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aw_best_v1_3.root"]
file = ["/data/HD5/users/brownd/nts.brownd.EventNtupleDeCalib.De.001430/00000/nts.brownd.EventNtupleDeCalib.De.001430_00000000.root"]
file = [" "]

# %%
momrange=[80,110]

# %%
ce = HistCe.HistCe(momrange,20,1e-5,0.8)

# %%
ce.Loop(file)
# Out:
# ['ntuple;1', 'version;1', 'n_proc_events;1']
# Processing batch
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ce.Loop(file)
#
# File ~/mu2e/pyana/RefAna/HistCe.py:97, in HistCe.Loop(self, files)
#      95 np.set_printoptions(precision=5,floatmode='fixed')
#      96 print("Processing batch ",end=' ')
# ---> 97 for batch,rep in uproot.iterate(files,filter_name="/evtinfo|trk|trksegs|trkmcsim|trksegsmc/i",report=True):
#      98     print(ibatch,end=' ')
#      99     ibatch = ibatch+1
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:199, in iterate(files, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, step_size, decompression_executor, interpretation_executor, library, ak_add_doc, how, report, custom_classes, allow_missing, **options)
# ...

# %%
ce.PlotTrackerMomentum()

# %%
ce.PlotTarget()

# %%
ce.Write("/data/HD5/users/rubyknudsen/HistCe.hdf5")
# write out to my HD5
