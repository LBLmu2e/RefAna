# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python312.zip', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12/lib-dynload', '', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import HistCe

# %%
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_debug_mc.root"]
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack.root" ]
#file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack_nofilter.root"]
#file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_test.root"]
#file = ["/data/HD6/users/brownd/ntp.CeEndpointOnSpill_full_CAFix.root"]
file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aw_best_v1_3.root"]

# %%
momrange=[80,110]

# %%
ce = HistCe.HistCe(momrange,20,1e-5,0.8)

# %%
ce.Loop(file)
# Out:
# ['ntuple;5', 'ntuple;4', 'version;1']
# Processing batch
# ---------------------------------------------------------------------------
# DeserializationError                      Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ce.Loop(file)
#
# File ~/RefAna/RefAna-MyFork/HistCe.py:97, in HistCe.Loop(self, files)
#      95 np.set_printoptions(precision=5,floatmode='fixed')
#      96 print("Processing batch ",end=' ')
# ---> 97 for batch,rep in uproot.iterate(files,filter_name="/evtinfo|trk|trksegs|trkmcsim|trksegsmc/i",report=True):
#      98     print(ibatch,end=' ')
#      99     ibatch = ibatch+1
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:193, in iterate(files, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, step_size, decompression_executor, interpretation_executor, library, ak_add_doc, how, report, custom_classes, allow_missing, **options)
#     191 with hasbranches:
#     192     try:
# --> 193         for item in hasbranches.iterate(
#     194             expressions=expressions,
#     195             cut=cut,
#     196             filter_name=filter_name,
#     197             filter_typename=filter_typename,
#     198             filter_branch=filter_branch,
#     199             aliases=aliases,
#     200             language=language,
#     201             step_size=step_size,
#     202             decompression_executor=decompression_executor,
#     203             interpretation_executor=interpretation_executor,
#     204             library=library,
#     205             ak_add_doc=ak_add_doc,
#     206             how=how,
#     207             report=report,
#     208         ):
#     209             if report:
#     210                 arrays, report = item
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:1066, in HasBranches.iterate(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, step_size, decompression_executor, interpretation_executor, library, ak_add_doc, how, report)
#    1064 arrays = {}
#    1065 interp_options = {"ak_add_doc": ak_add_doc}
# -> 1066 _ranges_or_baskets_to_arrays(
#    1067     self,
#    1068     ranges_or_baskets,
#    1069     branchid_interpretation,
#    1070     sub_entry_start,
#    1071     sub_entry_stop,
#    1072     decompression_executor,
#    1073     interpretation_executor,
#    1074     library,
#    1075     arrays,
#    1076     True,
#    1077     interp_options,
#    1078 )
#    1080 _fix_asgrouped(
#    1081     arrays,
#    1082     expression_context,
#    (...)
#    1086     ak_add_doc,
#    1087 )
#    1089 output = language.compute_expressions(
#    1090     self,
#    1091     arrays,
#    (...)
#    1096     self.object_path,
#    1097 )
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:3120, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3117     pass
#    3119 elif isinstance(obj, tuple) and len(obj) == 3:
# -> 3120     uproot.source.futures.delayed_raise(*obj)
#    3122 else:
#    3123     raise AssertionError(obj)
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/source/futures.py:38, in delayed_raise(exception_class, exception_value, traceback)
#      34 def delayed_raise(exception_class, exception_value, traceback):
#      35     """
#      36     Raise an exception from a background thread on the main thread.
#      37     """
# ---> 38     raise exception_value.with_traceback(traceback)
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/behaviors/TBranch.py:3063, in _ranges_or_baskets_to_arrays.<locals>.basket_to_array(basket)
#    3060         context = dict(branch.context)
#    3061         context["forth"] = forth_context[branch.cache_key]
# -> 3063         basket_array = interpretation.basket_array(
#    3064             basket.data,
#    3065             basket.byte_offsets,
#    3066             basket,
#    3067             branch,
#    3068             context,
#    3069             basket.member("fKeylen"),
#    3070             library,
#    3071             interp_options,
#    3072         )
#    3073         if basket.num_entries != len(basket_array):
#    3074             raise ValueError(
#    3075                 f"""basket {basket.basket_num} in tree/branch {branch.object_path} has the wrong number of entries """
#    3076                 f"""(expected {basket.num_entries}, obtained {len(basket_array)}) when interpreted as {interpretation}
#    3077 in file {branch.file.file_path}"""
#    3078             )
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/interpretation/objects.py:162, in AsObjects.basket_array(self, data, byte_offsets, basket, branch, context, cursor_offset, library, options)
#     151 assert basket.byte_offsets is not None
#     153 if self._forth and (
#     154     isinstance(
#     155         library,
#    (...)
#     160     )
#     161 ):
# --> 162     output = self.basket_array_forth(
#     163         data,
#     164         byte_offsets,
#     165         basket,
#     166         branch,
#     167         context,
#     168         cursor_offset,
#     169         library,
#     170         options,
#     171     )
#     173 else:
#     174     output = ObjectArray(
#     175         self._model, branch, context, byte_offsets, data, cursor_offset
#     176     ).to_numpy()
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/interpretation/objects.py:248, in AsObjects.basket_array_forth(self, data, byte_offsets, basket, branch, context, cursor_offset, library, options)
#     246 # this thread tries to do it!
#     247 try:
# --> 248     output = self._discover_forth(
#     249         data, byte_offsets, branch, context, cursor_offset
#     250     )
#     251 except CannotBeForth:
#     252     self._forth = False
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/interpretation/objects.py:408, in AsObjects._discover_forth(self, data, byte_offsets, branch, context, cursor_offset)
#     403 cursor = uproot.source.cursor.Cursor(
#     404     0, origin=-(byte_offsets[i] + cursor_offset)
#     405 )
#     407 context["forth"].gen.reset_active_node()
# --> 408 output[i] = self._model.read(
#     409     chunk, cursor, context, branch.file, branch.file.detached, branch
#     410 )
#     412 derived_form = context["forth"].gen.model.derive_form()
#     413 if not self._any_NULL(derived_form):
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/containers.py:1010, in AsVectorLike.read(self, chunk, cursor, context, file, selffile, parent, header)
#    1007     forth_obj.add_node(forth_stash)
#    1008     forth_obj.push_active_node(forth_stash)
# -> 1010 values = _read_nested(
#    1011     self._items,
#    1012     length,
#    1013     chunk,
#    1014     cursor,
#    1015     uproot._awkwardforth.add_to_path(
#    1016         forth_obj, context, uproot._awkwardforth.SpecialPathItem("item")
#    1017     ),
#    1018     file,
#    1019     selffile,
#    1020     parent,
#    1021 )
#    1023 if forth_obj is not None:
#    1024     forth_obj.pop_active_node()
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/containers.py:90, in _read_nested(model, length, chunk, cursor, context, file, selffile, parent, header)
#      87     forth_obj.set_active_node(original_model)
#      89 if isinstance(model, AsContainer):
# ---> 90     values[i] = model.read(
#      91         chunk,
#      92         cursor,
#      93         context,
#      94         file,
#      95         selffile,
#      96         parent,
#      97         header=header,
#      98     )
#      99 else:
#     100     values[i] = model.read(
#     101         chunk,
#     102         cursor,
#    (...)
#     106         parent,
#     107     )
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/containers.py:1010, in AsVectorLike.read(self, chunk, cursor, context, file, selffile, parent, header)
#    1007     forth_obj.add_node(forth_stash)
#    1008     forth_obj.push_active_node(forth_stash)
# -> 1010 values = _read_nested(
#    1011     self._items,
#    1012     length,
#    1013     chunk,
#    1014     cursor,
#    1015     uproot._awkwardforth.add_to_path(
#    1016         forth_obj, context, uproot._awkwardforth.SpecialPathItem("item")
#    1017     ),
#    1018     file,
#    1019     selffile,
#    1020     parent,
#    1021 )
#    1023 if forth_obj is not None:
#    1024     forth_obj.pop_active_node()
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/containers.py:100, in _read_nested(model, length, chunk, cursor, context, file, selffile, parent, header)
#      90         values[i] = model.read(
#      91             chunk,
#      92             cursor,
#    (...)
#      97             header=header,
#      98         )
#      99     else:
# --> 100         values[i] = model.read(
#     101             chunk,
#     102             cursor,
#     103             context,
#     104             file,
#     105             selffile,
#     106             parent,
#     107         )
#     109 return values
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/model.py:1362, in DispatchByVersion.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#    1354             raise ValueError(
#    1355                 f"""Unknown version {version} for class {classname_decode(cls.__name__)[0]} that cannot be skipped """
#    1356                 """because its number of bytes is unknown.
#    1357 """
#    1358             )
#    1360         # versioned_cls.read starts with numbytes_version again because move=False (above)
#    1361         temp_var = cls.postprocess(
# -> 1362             versioned_cls.read(
#    1363                 chunk, cursor, context, file, selffile, parent, concrete=concrete
#    1364             ),
#    1365             chunk,
#    1366             cursor,
#    1367             context,
#    1368             file,
#    1369         )
#    1371         if forth_obj is not None:
#    1372             forth_obj.pop_active_node()
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/model.py:862, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     856         forth_obj.pop_active_node()
#     858     self.hook_after_read_members(
#     859         chunk=chunk, cursor=cursor, context=context, file=file
#     860     )
# --> 862 self.check_numbytes(chunk, cursor, context)
#     864 self.hook_before_postprocess(
#     865     chunk=chunk, cursor=cursor, context=context, file=file
#     866 )
#     868 out = self.postprocess(chunk, cursor, context, file)
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/model.py:936, in Model.check_numbytes(self, chunk, cursor, context)
#     916 """
#     917 Args:
#     918     chunk (:doc:`uproot.source.chunk.Chunk`): Buffer of contiguous data
#    (...)
#     932 likely.
#     933 """
#     934 import uproot.deserialization
# --> 936 uproot.deserialization.numbytes_check(
#     937     chunk,
#     938     self._cursor,
#     939     cursor,
#     940     self._num_bytes,
#     941     self.classname,
#     942     context,
#     943     getattr(self._file, "file_path", None),
#     944 )
#
# File ~/miniconda3/envs/jupyter_env/lib/python3.12/site-packages/uproot/deserialization.py:175, in numbytes_check(chunk, start_cursor, stop_cursor, num_bytes, classname, context, file_path)
#     173 observed = stop_cursor.displacement(start_cursor)
#     174 if observed != num_bytes:
# --> 175     raise DeserializationError(
#     176         f"""expected {num_bytes} bytes but cursor moved by {observed} bytes (through {classname})""",
#     177         chunk,
#     178         stop_cursor,
#     179         context,
#     180         file_path,
#     181     )
#
# DeserializationError: while reading
#
#     mu2e::TrkStrawMatInfo version 0 as uproot.dynamic.Model_mu2e_3a3a_TrkStrawMatInfo_v1 (106 bytes)
#         active: False
#         plane: 0
#         panel: 0
#         layer: 256
#         straw: 0
#         doca: 5.0222536961401444e-42
#         tlen: 1.1658803223182478e-42
#         dp: 1.3447361499819264e-34
#         radlen: 0.0
# Members for mu2e::TrkStrawMatInfo: (active), (plane), (panel), (layer), (straw), (doca), (tlen), (dp), (radlen)
#
# expected 106 bytes but cursor moved by 43 bytes (through mu2e::TrkStrawMatInfo)
# in file /data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aw_best_v1_3.root
# in object /EventNtuple/ntuple;5

# %%
ce.PlotTrackerMomentum()

# %%
ce.PlotTarget()

# %%
ce.Write("/data/HD5/users/rubyknudsen/HistCe.hdf5")
# write out to my HD5
# Out:
# Saved /OriginMom/MC Origin to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_FrontMom/Fit to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_FrontMom/MC to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_FrontResolution/ to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_FrontResponse/All to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_FrontResponse/Reflectable to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_MidMom/Fit to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_MidMom/MC to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_MidResolution/ to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_MidResponse/All to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_MidResponse/Reflectable to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_BackMom/Fit to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_BackMom/MC to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_BackResolution/ to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_BackResponse/All to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /TT_BackResponse/Reflectable to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtRho/Fit to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtRho/MC to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtRho/MC Origin to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtFoil/Fit to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtFoil/MC to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtFoil/MC Origin to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtCosT/Fit to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtCosT/MC to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /HTgtCosT/MC Origin to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /DMom/B12 to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /DMom/B34 to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /DMom/B56 to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /DMom/B78 to /data/HD5/users/rubyknudsen/HistCe.hdf5
# Saved /DMom/B9p to /data/HD5/users/rubyknudsen/HistCe.hdf5
