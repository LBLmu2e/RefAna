# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages', '/cvmfs/mu2e.opensciencegrid.org/spackages/241207/spack/opt/spack/linux-almalinux9-x86_64_v2/gcc-11.5.0/muse-4.17.0-di7thnqtj43r5ojxh6gum5pqg42mwmn2/python', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python312.zip', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/lib-dynload', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import CeAna
import SurfaceIds

# %%
sids =[0,1,2]
momrange=[80,110]

# %%
ce = CeAna.CeAna(momrange,20,0.0,sids)

# %%
file = ["/data/HD5/users/brownd/ntp.mu2e.CeEndpointOnSpill_KKGeom.root"]
#/data/HD5/users/brownd/nts.brownd.EventNtupleDeCalib.De.001430/00000/nts.brownd.EventNtupleDeCalib.De.001430_00000000.root"]
#file = ["/data/HD5/users/brownd/ntp.brownd.RefRegrowe.root"]
file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2025ae_best_v1_3.root"]

# %%
ce.Loop(file)
# Out:
# ['ntuple;1', 'version;1', 'n_proc_events;1']
# [{event: 2, run: 1430, subrun: 9, nprotons: 0, pbtime: -218, ...}, ..., {...}] <class 'awkward.highlevel.Array'>
# Processing batch  0
# 938 985 938 985
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ce.Loop(file)
#
# File ~/mu2e/pyana/RefAna/CeAna.py:130, in CeAna.Loop(self, files)
#     128 hasMC = ak.count_nonzero(momMC,axis=1)==1
#     129 print(len(hasMC),len(goodFit),len(hasmom),len(noTSDA))
# --> 130 select = hasMC & goodFit & hasmom & noTSDA
#     131 mom = mom[select]
#     132 momMC = momMC[select]
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/_operators.py:54, in _binary_method.<locals>.func(self, other)
#      51 if _disables_array_ufunc(other):
#      52     return NotImplemented
# ---> 54 return ufunc(self, other)
#
# ...
