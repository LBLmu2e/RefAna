# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import PlotReflections

# %%
refplot = PlotReflections.PlotReflections("/data/HD5/users/brownd/HistReflections_test.hdf5")
# Out:
# Read  MyHist /HUpTQ/Up TrkQual with 100 bins and 3436 entries
# Read  MyHist /HDnTQ/Down TrkQual with 100 bins and 3436 entries
# Read  MyHist /HUpFitCon/Up FitCon with 100 bins and 3436 entries
# Read  MyHist /HDnFitCon/Down FitCon with 100 bins and 3436 entries
# Read  MyHist /HUpNHits/Up NActive with 100 bins and 3392 entries
# Read  MyHist /HDnNHits/Down NActive with 100 bins and 3379 entries
# Read  MyHist /NInter/All ST with 15 bins and 38579 entries
# Read  MyHist /NInter/All IPA with 15 bins and 38573 entries
# Read  MyHist /NInter/Target ST with 15 bins and 3436 entries
# Read  MyHist /NInter/Target IPA with 15 bins and 3436 entries
# Read  MyHist /DnMom/All with 100 bins and 35806 entries
# Read  MyHist /DnMom/$N_{ST}$>0 with 100 bins and 3436 entries
# Read  MyHist /DnMom/$N_{ST}$==0 with 100 bins and 6366 entries
# Read  MyHist /DnMom/$N_{IPA}$==0 with 100 bins and 6952 entries
# Read  MyHist /DnMom/No Material with 100 bins and 6951 entries
# Read  MyHist /UpMom/All with 100 bins and 35811 entries
# Read  MyHist /UpMom/$N_{ST}$>0 with 100 bins and 3436 entries
# Read  MyHist /UpMom/$N_{ST}$==0 with 100 bins and 6366 entries
# Read  MyHist /UpMom/$N_{IPA}$==0 with 100 bins and 6951 entries
# Read  MyHist /UpMom/No Material with 100 bins and 6950 entries
# Read  MyHist /DeltaMom/All with 200 bins and 35732 entries
# Read  MyHist /DeltaMom/$N_{ST}$>0 with 200 bins and 3410 entries
# Read  MyHist /DeltaMom/$N_{ST}$==0 with 200 bins and 6362 entries
# Read  MyHist /DeltaMom/$N_{IPA}$==0 with 200 bins and 6958 entries
# Read  MyHist /DeltaMom/No Material with 200 bins and 6957 entries

# %%
refplot.PlotIntersections()

# %%
refplot.PlotMomentum()

# %%
refplot.PlotQuality()
