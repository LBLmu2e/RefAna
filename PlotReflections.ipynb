# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python312.zip', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12/lib-dynload', '', '/home/online1/rubyknudsen/miniconda3/envs/jupyter_env/lib/python3.12/site-packages', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import PlotReflections

# %%
refplot = PlotReflections.PlotReflections("/data/HD5/users/rubyknudsen/HistReflections_BinnedFoilHits_073125.hdf5")
# Out:
# Read  MyHist /HUpTQ/Up TrkQual with 100 bins and 176405 entries
# Read  MyHist /HDnTQ/Down TrkQual with 100 bins and 176406 entries
# Read  MyHist /HUpFitCon/Up FitCon with 100 bins and 176406 entries
# Read  MyHist /HDnFitCon/Down FitCon with 100 bins and 176406 entries
# Read  MyHist /HUpNHits/Up NActive with 100 bins and 174220 entries
# Read  MyHist /HDnNHits/Down NActive with 100 bins and 173964 entries
# Read  MyHist /NInter/All ST with 20 bins and 38579 entries
# Read  MyHist /NInter/All IPA with 20 bins and 38579 entries
# Read  MyHist /NInter/Target ST with 20 bins and 3436 entries
# Read  MyHist /NInter/Target IPA with 20 bins and 3436 entries
# Read  MyHist /DnMom/All with 100 bins and 35806 entries
# Read  MyHist /DnMom/Target with 100 bins and 3436 entries
# Read  MyHist /DnMom/No Target with 100 bins and 6366 entries
# Read  MyHist /DnMom/No IPA with 100 bins and 6952 entries
# Read  MyHist /DnMom/No Mat with 100 bins and 6951 entries
# Read  MyHist /UpMom/All with 100 bins and 35811 entries
# Read  MyHist /UpMom/Target with 100 bins and 3436 entries
# Read  MyHist /UpMom/No Target with 100 bins and 6366 entries
# Read  MyHist /UpMom/No IPA with 100 bins and 6951 entries
# Read  MyHist /UpMom/No Mat with 100 bins and 6950 entries
# Read  MyHist /DeltaMom/All with 200 bins and 35732 entries
# Read  MyHist /DeltaMom/Target with 200 bins and 3410 entries
# Read  MyHist /DeltaMom/No Target with 200 bins and 6362 entries
# Read  MyHist /DeltaMom/No IPA with 200 bins and 6958 entries
# Read  MyHist /DeltaMom/No Mat with 200 bins and 6957 entries
# Read  MyHist /UpMom/B12 with 100 bins and 1459 entries
# Read  MyHist /UpMom/B34 with 100 bins and 1319 entries
# Read  MyHist /UpMom/B56 with 100 bins and 624 entries
# Read  MyHist /UpMom/B78 with 100 bins and 416 entries
# Read  MyHist /UpMom/B9p with 100 bins and 91 entries
# Read  MyHist /DnMom/B12 with 100 bins and 1459 entries
# Read  MyHist /DnMom/B34 with 100 bins and 1319 entries
# Read  MyHist /DnMom/B56 with 100 bins and 624 entries
# Read  MyHist /DnMom/B78 with 100 bins and 416 entries
# Read  MyHist /DnMom/B9p with 100 bins and 91 entries
# Read  MyHist /DeltaMom/B12 with 200 bins and 1451 entries
# Read  MyHist /DeltaMom/B34 with 200 bins and 1313 entries
# Read  MyHist /DeltaMom/B56 with 200 bins and 617 entries
# Read  MyHist /DeltaMom/B78 with 200 bins and 412 entries
# Read  MyHist /DeltaMom/B9p with 200 bins and 91 entries

# %%
refplot.PlotIntersections()

# %%
refplot.PlotMomentum()

# %%
refplot.PlotQuality()

# %%
refplot.PlotBinnedMomentums()
