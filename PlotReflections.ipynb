# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages', '/cvmfs/mu2e.opensciencegrid.org/spackages/241207/spack/opt/spack/linux-almalinux9-x86_64_v2/gcc-11.5.0/muse-4.17.0-di7thnqtj43r5ojxh6gum5pqg42mwmn2/python', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python312.zip', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/lib-dynload', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import PlotReflections

# %%
#refplot = PlotReflections.PlotReflections("/data/HD5/users/rubyknudsen/HistReflections_BinnedFoilHits_073125.hdf5")
refplot = PlotReflections.PlotReflections("/data/HD5/users/brownd/HistRefe.hd5")
refplot = PlotReflections.PlotReflections("/data/HD5/users/brownd/HistRefmu.hd5")
# Out:
# Read  MyHist /HUpTQ/Up TrkQual with 100 bins and 491 entries
# Read  MyHist /HDnTQ/Down TrkQual with 100 bins and 491 entries
# Read  MyHist /HUpFitCon/Up FitCon with 100 bins and 491 entries
# Read  MyHist /HDnFitCon/Down FitCon with 100 bins and 491 entries
# Read  MyHist /HUpNHits/Up NActive with 100 bins and 472 entries
# Read  MyHist /HDnNHits/Down NActive with 100 bins and 474 entries
# Read  MyHist /NInter/All ST with 15 bins and 8206 entries
# Read  MyHist /NInter/All IPA with 15 bins and 8053 entries
# Read  MyHist /NInter/Target ST with 15 bins and 491 entries
# Read  MyHist /NInter/Target IPA with 15 bins and 477 entries
# Read  MyHist /DnMom/All with 100 bins and 5396 entries
# Read  MyHist /DnMom/$N_{ST}$>0 with 100 bins and 330 entries
# Read  MyHist /DnMom/$N_{ST}$==0 with 100 bins and 746 entries
# Read  MyHist /DnMom/$N_{IPA}$==0 with 100 bins and 1052 entries
# Read  MyHist /DnMom/No Material with 100 bins and 1052 entries
# ...

# %%
refplot.PlotIntersections()

# %%
refplot.PlotMomentum()

# %%
refplot.PlotQuality()

# %%
#refplot.PlotBinnedMomentums()
